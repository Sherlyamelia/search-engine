# %%
with open('features_with_labels.pkl', 'rb') as file:
    data = pkl.load(file)

# Pisahkan data menjadi fitur, label, dan nama file
Image_features = data[0]  # Elemen pertama adalah fitur gambar
labels = data[1]          # Elemen kedua adalah label gambar
filenames = data[2]       # Elemen ketiga adalah nama file gambar

# Validasi
print(f"Jumlah fitur: {len(Image_features)}")
print(f"Jumlah label: {len(labels)}")
print(f"Jumlah nama file: {len(filenames)}")

# Pastikan jumlah data konsisten
assert len(Image_features) == len(labels) == len(filenames), "Jumlah elemen tidak konsisten!"
print("Data berhasil dipisahkan.")
# Out:
# Jumlah fitur: 11961
# Jumlah label: 11961
# Jumlah nama file: 11961
# Data berhasil dipisahkan.

# %%
with open('Image_features.pkl', 'wb') as file:
    pkl.dump(Image_features, file)

# %%
with open('labels.pkl', 'wb') as file:
    pkl.dump(labels, file)

# %%
with open('filenames.pkl', 'wb') as file:
    pkl.dump(filenames, file)

# %%
with open('filenames.pkl', 'rb') as file:
    filenames = pkl.load(file)

print("Nama file yang dimuat:", filenames)
# Out:
# Nama file yang dimuat: ['images\\1163.jpg', 'images\\1164.jpg', 'images\\1165.jpg', 'images\\1525.jpg', 'images\\1526.jpg', 'images\\1528.jpg', 'images\\1529.jpg', 'images\\1530.jpg', 'images\\1531.jpg', 'images\\1532.jpg', 'images\\1533.jpg', 'images\\1534.jpg', 'images\\1535.jpg', 'images\\1536.jpg', 'images\\1537.jpg', 'images\\1538.jpg', 'images\\1539.jpg', 'images\\1540.jpg', 'images\\1541.jpg', 'images\\1542.jpg', 'images\\1543.jpg', 'images\\1544.jpg', 'images\\1545.jpg', 'images\\1546.jpg', 'images\\1547.jpg', 'images\\1548.jpg', 'images\\1549.jpg', 'images\\1556.jpg', 'images\\1557.jpg', 'images\\1559.jpg', 'images\\1561.jpg', 'images\\1562.jpg', 'images\\1563.jpg', 'images\\1565.jpg', 'images\\1566.jpg', 'images\\1567.jpg', 'images\\1569.jpg', 'images\\1570.jpg', 'images\\1571.jpg', 'images\\1572.jpg', 'images\\1573.jpg', 'images\\1575.jpg', 'images\\1577.jpg', 'images\\1578.jpg', 'images\\1579.jpg', 'images\\1580.jpg', 'images\\1583.jpg', 'images\\1584.jpg', 'images\\1587.
# ...

# %%
import os
import pickle as pkl

# Contoh data dengan jalur lengkap
file_paths = ['images\\38167.jpg', 'images\\29894.jpg', 'images\\38224.jpg']

# Hanya ambil nama file
file_names = [os.path.basename(path) for path in file_paths]

# Simpan hanya nama file ke filenames.pkl
with open('filenames.pkl', 'wb') as file:
    pkl.dump(file_names, file)

print("Data yang disimpan:", file_names)
# Out:
# Data yang disimpan: ['38167.jpg', '29894.jpg', '38224.jpg']

# %%
with open('filenames.pkl', 'wb') as file:
    pkl.dump(filenames, file)

# %%
import os
import pickle as pkl
with open('labels.pkl', 'rb') as file:
    labels = pkl.load(file)

print("Nama file yang dimuat:", labels)
# Out:
# Nama file yang dimuat: ['Tshirts', 'Tshirts', 'Tshirts', 'Backpacks', 'Backpacks', 'Jackets', 'Tshirts', 'Jackets', 'Tshirts', 'Tshirts', 'Tshirts', 'Tshirts', 'Caps', 'Tshirts', 'Tshirts', 'Tshirts', 'Tshirts', 'Tshirts', 'Sports Shoes', 'Sports Shoes', 'Casual Shoes', 'Casual Shoes', 'Casual Shoes', 'Casual Shoes', 'Casual Shoes', 'Sports Shoes', 'Sports Shoes', 'Backpacks', 'Backpacks', 'Backpacks', 'Tshirts', 'Tshirts', 'Tshirts', 'Backpacks', 'Caps', 'Shorts', 'Shorts', 'Tshirts', 'Sports Shoes', 'Track Pants', 'Track Pants', 'Tshirts', 'Caps', 'Tshirts', 'Jackets', 'Swimwear', 'Swimwear', 'Jackets', 'Sports Shoes', 'Tshirts', 'Sports Shoes', 'Shorts', 'Sports Shoes', 'Casual Shoes', 'Tshirts', 'Handbags', 'Handbags', 'Handbags', 'Sweatshirts', 'Track Pants', 'Track Pants', 'Track Pants', 'Track Pants', 'Sweatshirts', 'Jackets', 'Jackets', 'Tshirts', 'Tshirts', 'Tshirts', 'Tshirts', 'Tshirts', 'Tshirts', 'Sports Shoes', 'Shorts', 'Shorts', 'Shorts', 'Jackets', 'Backpacks', 'Back
# ...

# %%
import pickle as pkl

# Muat features_with_labels.pkl
with open('features_with_labels.pkl', 'rb') as file:
    data = pkl.load(file)

# Pisahkan data menjadi fitur, label, dan nama file
Image_features = data[0]  # Elemen pertama adalah fitur gambar
labels = data[1]          # Elemen kedua adalah label gambar
filenames = data[2]       # Elemen ketiga adalah nama file gambar

# Validasi
print(f"Jumlah fitur: {len(Image_features)}")
print(f"Jumlah label: {len(labels)}")
print(f"Jumlah nama file: {len(filenames)}")

# Pastikan jumlah data konsisten
assert len(Image_features) == len(labels) == len(filenames), "Jumlah elemen tidak konsisten!"
print("Data berhasil dipisahkan.")

# Gabungkan filenames dan labels menjadi dictionary
labels_dict = {filenames[i]: labels[i] for i in range(len(filenames))}

# Tampilkan hasil dictionary
print(labels_dict)
# Out:
# Jumlah fitur: 11961
# Jumlah label: 11961
# Jumlah nama file: 11961
# Data berhasil dipisahkan.
# ...

# %%
import pickle as pkl

# Gabungkan filenames dan labels menjadi dictionary
labels_dict = {filenames[i]: labels[i] for i in range(len(filenames))}

# Menyimpan dictionary ke file pickle
with open('labels_dict.pkl', 'wb') as f:
    pkl.dump(labels_dict, f)

print("labels_dict berhasil disimpan ke labels_dict.pkl")
# Out:
# labels_dict berhasil disimpan ke labels_dict.pkl
